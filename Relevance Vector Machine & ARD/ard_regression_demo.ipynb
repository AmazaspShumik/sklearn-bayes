# %%
# vim: set filetype=python:

# %% [markdown]
# # Notes on Sparse Bayesian Learning: ARD regression and Relevance Vector machine

# %% [markdown]
# Automatic Relevance Determination is very similar to Bayesian Regression with evidence approximation and Normal prior on weights. The only difference is that in ARD framework prior distribution does not have single precision shared by all parameters (except bias term), instead each parameter is initially assigned with its own varince. In the process of type II maximum likelihood maximization variance for some parameters comes close to zero, so after several iterations those parameters can be discarded, since they have zero mean and almost zero variance in prior distribution.
#
# There are three different methods for fitting ARD regression, first two of them fixed-point and expectation maximization were proposed by Tipping in his original paper (Tipping(2001)), third one was discovered year later. In current version of code only fixed-point and EM algorithms are implemented, in general EM is a little slower so by default model is fitted with fixed-point algorithm.
#
# One of the main drawbacks of ARD is that it is non convex optimization problem therefore there is chance of ending up in local maximum, so it may be a good idea to rerun algorithm couple of times.

# %% [markdown]
# ## ARD regression

# %% [markdown]
# ### Variable Selection

# %% [markdown]
# Below is example of using ARD regression, in this example only one variable out of 100 is relevant. Plots show ARD correctly identified single relevant feature (single blue point above red line), you can also see that both EM and fixed-point algorithms had similar results.

# %%
import numpy as np
from rvm import SparseBayesianLearner
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline


# generate training & test data
np.random.seed(0)
X                             = np.random.random([500,100])
X[:,0]                        = np.linspace(start = 0,stop = 10, num = 500)
Y                             = 10*X[:,0]  + np.random.normal(0,1,500)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2)

# fit data with EM & fixed-point
ard_regression_em             = SparseBayesianLearner(learn_type = "regression",
                                                      method = "EM",
                                                      alpha_max = 1)
ard_regression_fp             = SparseBayesianLearner(learn_type = "regression",
                                                      method = "fixed-point",
                                                      alpha_max = 1)
ard_regression_em.fit(X_train,Y_train)
ard_regression_fp.fit(X_train,Y_train)

# plot variance of parameters in prior
fp = plt.plot(np.log(1./ard_regression_fp.diagA),"bo")
plt.xlabel("feature index")
plt.ylabel("log of variance of feature in prior")
plt.title("ARD regression with fixed-point fitter")
plt.plot(np.zeros(100),"r-", linewidth = 2)
plt.show()

em = plt.plot(np.log(1./ard_regression_em.diagA),"bo")
plt.xlabel("feature index")
plt.ylabel("log of variance of feature in prior")
plt.title("ARD regression with EM fitter")
plt.plot(np.zeros(100),"r-", linewidth = 2)
plt.show()

print "number of variables selected wiht EM fitter " + str(np.sum(ard_regression_em.active))
print "number of variables selected wiht fixed-point fitter " + str(np.sum(ard_regression_fp.active))
# Out:
# number of variables selected wiht EM fitter 1
# number of variables selected wiht fixed-point fitter 1

# %% [markdown]
# ### EM vs Fixed-Point algorithms for fitting RVM

# %% [markdown]
# Problem with variable selection with ARD framework is that user needs to determine threshold for parameter variance, and model sparsity is directly determined by this threshold. Plot below shows that relationship. You can also see that EM and fixed-point fitting algorithms give almost similar results.

# %%
em_vars_selected = []
fp_vars_selected = []
for alpha_max_i in xrange(1,100):
     ard_regression_em_i  = SparseBayesianLearner( method = "EM",alpha_max = alpha_max_i)
     ard_regression_fp_i  = SparseBayesianLearner(method = "fixed-point",alpha_max = alpha_max_i)
     ard_regression_em_i.fit(X_train, Y_train, )
     ard_regression_fp_i.fit(X_train, Y_train, )
     em_vars_selected.append(np.sum(ard_regression_em_i.active))
     fp_vars_selected.append(np.sum(ard_regression_fp_i.active))
        
plt.plot(np.log(sorted(1./np.linspace(1,100,99))), em_vars_selected,"ro", 
                                                                    markersize = 10, 
                                                                    label = "EM")
plt.plot(np.log(sorted(1./np.linspace(1,100,99))), fp_vars_selected,"b+", 
                                                                    markersize = 10, 
                                                                    label = "Fixed Point")
plt.ylim((-5,50))
plt.xlabel("log of threshold variance")
plt.ylabel("number of variables selected")
plt.legend(loc = 4)
plt.show()

# %% [markdown]
# ### Predictions

# %% [raw]
#  After fitting model we can make point predictions using mean of predictive distribution.

# %%
# mean of predictive distribution
mu   = ard_regression_fp.predict(X_test)

plt.plot(X_test[:,0],Y_test,"bo", markersize = 8, label = "Data")
plt.plot(X_test[:,0],mu    ,"r-", linewidth = 4, label = "fitted model")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc = 4)
plt.title("Prediction vs Test Data")
plt.show()

# %% [markdown]
# ### Perfect Multicollinearity and zero noise example

# %%
X   = np.array([ [ 0.1,  -0.1,  -0.2,   0.02],
                [ 0.3,  -0.3,  -0.6,   0.06],
                [ 0.4,  -0.4,  -0.8,   0.08],
                [ 0.5,  -0.5,  -1.,    0.1 ]])

Y   = np.array([ 0.2,  0.6,  0.8,  1.])
ard_fp =  SparseBayesianLearner(learn_type = "regression",
                             method     = "fixed-point",
                             alpha_max  = 100)
ard_fp.fit(X,Y)
y_fp, var_fp = ard_fp.predictive_distribution(X)

ard_em =  SparseBayesianLearner(learn_type = "regression",
                                method     = "EM",
                                alpha_max  = 100)
ard_em.fit(X,Y)
y_em, var_em = ard_em.predictive_distribution(X)

# %%
print '\n Fixed Point vs EM, point predictions \n'
print  y_fp
print  y_em

print '\n Fixed Point vs EM, variance of predictive distribution \n'
print var_fp
print var_em
# Out:
#  Fixed Point vs EM, point predictions
#
# [ 0.19999998  0.59999995  0.79999994  0.99999992]
# [ 0.19999998  0.59999994  0.79999993  0.99999991]
#
#  Fixed Point vs EM, variance of predictive distribution
#
# [  1.64718018e-07   1.90059250e-07   2.12232828e-07   2.40741713e-07]
# [  1.90685813e-07   2.20022089e-07   2.45691330e-07   2.78694641e-07]

# %% [markdown]
# This example's aim is mainly to show & test numerical stability of algorithm in case of perfect multicollinearity & zero noise.
# ( Thanks to Sergey Feldman for example & finding error in code)
